# %%
# load packages in the tidyverse library
library(tidyverse)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang
# Registered S3 method overwritten by 'rvest':
#   method            from
#   read_xml.response xml2
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.1       ✔ purrr   0.3.2
# ✔ tibble  2.1.1       ✔ dplyr   0.8.0.1
# ✔ tidyr   0.8.3       ✔ stringr 1.4.0
# ✔ readr   1.3.1       ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
print(mpg)
# Out:
# # A tibble: 234 x 11
#    manufacturer model    displ  year   cyl trans   drv     cty   hwy fl    class
#    <chr>        <chr>    <dbl> <int> <int> <chr>   <chr> <int> <int> <chr> <chr>
#  1 audi         a4         1.8  1999     4 auto(l… f        18    29 p     comp…
#  2 audi         a4         1.8  1999     4 manual… f        21    29 p     comp…
#  3 audi         a4         2    2008     4 manual… f        20    31 p     comp…
#  4 audi         a4         2    2008     4 auto(a… f        21    30 p     comp…
#  5 audi         a4         2.8  1999     6 auto(l… f        16    26 p     comp…
#  6 audi         a4         2.8  1999     6 manual… f        18    26 p     comp…
#  7 audi         a4         3.1  2008     6 auto(a… f        18    27 p     comp…
#  8 audi         a4 quat…   1.8  1999     4 manual… 4        18    26 p     comp…
#  9 audi         a4 quat…   1.8  1999     4 auto(l… 4        16    25 p     comp…
# ...

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = cty, color = class))
# Out:
# plot without title

# %%
# we can add the layer "scale_color_manual" to alter the color scheme
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = cty, color = class)) +
  scale_color_manual(values=c("red", "blue", "green", "purple", "yellow", "black", "cyan"))
# Out:
# plot without title

# %%
# note the differences in parentheses
#sp <- ggplot(data = mpg) + 
#        geom_point(mapping = aes(x = displ, y = cty, color = class))
#sp

(sp <- ggplot(data = mpg) + 
        geom_point(mapping = aes(x = displ, y = cty, color = class)))
# Out:
# plot without title

# %%
sp + scale_color_manual(values=c("red", "blue", "green", "purple", "yellow", "black", "cyan"))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2) # nrow is an optional argument!
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_grid(class ~ drv)
# Out:
# plot without title

# %% [markdown]
# 1. Try out a few different facet grids!
# 2. Run the following two blocks of code. What happened?

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(. ~ class)
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(class ~ .)
# Out:
# plot without title

# %% [markdown]
# There are other layers besides point layers.

# %%
ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
?geom_smooth

# %%
ggplot(data = mpg) + 
  geom_smooth(mapping = aes(x = displ, y = hwy, color = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# The structure of ggplot allows for a lot of flexibility

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth()

ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point(mapping = aes(color = class)) + 
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# plot only data points whose class is "subcompact"
ggplot(data = filter(mpg, class == "subcompact"), mapping = aes(x = displ, y = hwy)) + 
  geom_point() + 
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# See all loaded datasets
data()

# %% [markdown]
# ### In-class activity
# 1. Visualize the relationship between the variables city mpg, highway mpg, and engine displacement using three different methods. Use facet_wrap for one of these methods.
#  * In your opinion, which communicates the relationship between these three variables the best? What is that relationship?
#  * What happened when you used facet_wrap? Why?
# 2. Use geom_point to visualize engine displacement, highway mpg, and year.
#  * Which variable should be mapped to a point aesthetic rather than x or y values?
# 3. Recreate the following graph:
#
# ![graph](https://d33wubrfki0l68.cloudfront.net/9a3c63edfc170c576ec5d34faa90df2dc2a43443/7f9e5/visualize_files/figure-html/unnamed-chunk-28-5.png)
#
#  (Hint: try out the different aesthetics in geom_smooth)
#
# 4. Use facet grid to visualize four variables.
#  * Which variables did you use for x and y, and which for the grid? Why?
#  * Are there empty plots? Why or why not?
# 5. Add the layer geom_jitter() to the scatter plot mapping highway mpg versus engine displacement.
#  * What happened?
#  * Why might you want to do this?

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = hwy, y = cty, alpha = displ), size = 7)
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = hwy, y = cty)) +
 geom_point() +
 facet_wrap(. ~ displ)
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
 geom_point(mapping = aes(alpha = year))
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) + 
  geom_point(mapping = aes(color = drv), size = 4) + 
  geom_smooth(mapping = aes(linetype = drv), se=F)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
